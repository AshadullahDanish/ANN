# %% [markdown]
# <a href="https://www.kaggle.com/code/ashadullah/word2vec?scriptVersionId=170346636" target="_blank"><img align="left" alt="Kaggle" title="Open in Kaggle" src="https://kaggle.com/static/images/open-in-kaggle.svg"></a>

# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/game-of-thrones-books/004ssb.txt
# /kaggle/input/game-of-thrones-books/005ssb.txt
# /kaggle/input/game-of-thrones-books/001ssb.txt
# /kaggle/input/game-of-thrones-books/002ssb.txt
# /kaggle/input/game-of-thrones-books/003ssb.txt

# %%
# !pip install nltk

# %% [markdown]
# **Importing necessary library**

# %%
import numpy as np
import pandas as pd
import gensim
import os
from nltk import sent_tokenize
from gensim.utils import simple_preprocess

# %%
# !pip install gensim

# %%
import nltk
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to /usr/share/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %% [markdown]
# **Reading the Data**

# %%
data = ["/kaggle/input/game-of-thrones-books/004ssb.txt","/kaggle/input/game-of-thrones-books/005ssb.txt",
        "/kaggle/input/game-of-thrones-books/001ssb.txt","/kaggle/input/game-of-thrones-books/002ssb.txt",
        "/kaggle/input/game-of-thrones-books/003ssb.txt"]

# %% [markdown]
# **Tokenization**

# %%
story = []
for filepath in data:
    with open(filepath, 'r', encoding='latin-1') as file:
        corpus = file.read()
        raw_sent = sent_tokenize(corpus)
        for sent in raw_sent:
            story.append(simple_preprocess(sent))

# %%
len(story)
# Out:
# 145018

# %%
from sklearn.decomposition import PCA

# %%
model = gensim.models.Word2Vec(window=10,min_count=2)

# %%
model.build_vocab(story)

# %%
model.train(story,total_examples=model.corpus_count, epochs= model.epochs)
# Out:
# (6571631, 8628190)

# %%
model.wv.most_similar("dragon")
# Out:
# [('westeros', 0.6388123035430908),
#  ('sea', 0.6338644027709961),
#  ('dragons', 0.626207172870636),
#  ('star', 0.6133405566215515),
#  ('qarth', 0.610872209072113),
#  ('world', 0.6070348024368286),
#  ('god', 0.6025052666664124),
#  ('khalasar', 0.5940982699394226),
#  ('meereen', 0.5903194546699524),
#  ('seven', 0.5899342894554138)]

# %%
model.wv.doesnt_match(['jon','rikon','robb','arya','sansa','bran'])
# Out:
# 'jon'

# %%
model.wv.doesnt_match(['cersei', 'jaime', 'bronn', 'tyrion'])
# Out:
# 'bronn'

# %%
model.wv["jon"]
# Out:
# array([ 0.00924034, -0.28779748,  1.1767917 ,  0.45840308,  2.4909494 ,
#        -0.1834377 ,  1.6699184 ,  0.6537591 , -2.9157097 ,  0.709141  ,
#        -1.5480177 ,  0.87551796, -0.19167425, -1.6149929 , -0.18439245,
#         0.29311544,  2.2708702 ,  4.3538685 , -0.21681015, -0.31999937,
#         1.5951924 , -0.04191222, -0.38050327,  1.5598824 , -1.5228801 ,
#        -1.1105663 , -0.01778739, -0.7806504 ,  0.45072672,  0.04928547,
#        -1.6582757 , -0.994414  ,  0.94774675, -0.89684665,  1.4661027 ,
#        -0.45423406, -0.46029758,  1.6956755 ,  1.3139048 ,  1.17818   ,
#        -2.0672271 , -2.1185617 ,  0.9125716 ,  0.31811583,  2.7049308 ,
#        -1.6719139 , -1.9974602 ,  1.6366587 ,  1.013271  , -0.24210094,
#        -0.38414767,  0.04829821,  1.4666041 ,  0.01298161, -0.41650558,
#        -0.40603286, -0.05313075, -3.788161  ,  0.74783576, -0.9317714 ,
#         0.4994258 ,  0.7698167 , -0.00965672, -0.7282058 ,  1.5401235 ,
# ...

# %%
model.wv.similarity('arya','sansa')
# Out:
# 0.84269416

# %%
model.wv.similarity('cersei','sansa')
# Out:
# 0.73411036

# %%
model.wv.similarity('tywin','sansa')
# Out:
# 0.21840018

# %%
model.wv.get_normed_vectors()
# Out:
# array([[-0.10172188, -0.08012092,  0.01094667, ..., -0.18536705,
#          0.04678569,  0.13627434],
#        [-0.21766445, -0.01716547,  0.00321836, ...,  0.03952565,
#          0.08963011,  0.12267263],
#        [ 0.18396276, -0.00823828, -0.1226175 , ..., -0.00735311,
#          0.18608388, -0.16073243],
#        ...,
#        [-0.10808755,  0.09811591, -0.01079356, ..., -0.143341  ,
#          0.21025562, -0.02997047],
#        [ 0.08491658,  0.05939539, -0.0580464 , ...,  0.13158399,
#          0.00272573,  0.02628144],
#        [ 0.01796457,  0.04707677,  0.0996068 , ...,  0.00579897,
#         -0.09964506,  0.02570286]], dtype=float32)

# %%
y = model.wv.index_to_key

# %%
y[20:30]
# Out:
# ['they', 'is', 'at', 'on', 'said', 'my', 'have', 'be', 'lord', 'them']

# %%
from sklearn.decomposition import PCA  #we are going to use pca to reduce dimentaonality from 100 to 3d space

# %%
pca = PCA(n_components=3)

# %%
X = pca.fit_transform(model.wv.get_normed_vectors())

# %%
X.shape
# Out:
# (17453, 3)

# %%
# !pip install plotly

# %% [markdown]
# **Visulization**

# %%
import plotly.express as px
fig = px.scatter_3d(X[100:400],x=0,y=1,z=2, color=y[100:400])
fig.show()
# Out:
# /opt/conda/lib/python3.10/site-packages/plotly/express/_core.py:2065: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   sf: grouped.get_group(s if len(s) > 1 else s[0])
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.27.0.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
# ...
