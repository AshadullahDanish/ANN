# %% [markdown]
# <a href="https://www.kaggle.com/code/ashadullah/word2vec?scriptVersionId=168330980" target="_blank"><img align="left" alt="Kaggle" title="Open in Kaggle" src="https://kaggle.com/static/images/open-in-kaggle.svg"></a>

# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/game-of-thrones-books/004ssb.txt
# /kaggle/input/game-of-thrones-books/005ssb.txt
# /kaggle/input/game-of-thrones-books/001ssb.txt
# /kaggle/input/game-of-thrones-books/002ssb.txt
# /kaggle/input/game-of-thrones-books/003ssb.txt

# %%
# !pip install nltk
# Out:
# Requirement already satisfied: nltk in /opt/conda/lib/python3.10/site-packages (3.2.4)
# Requirement already satisfied: six in /opt/conda/lib/python3.10/site-packages (from nltk) (1.16.0)

# %%
import numpy as np
import pandas as pd
import gensim
import os
from nltk import sent_tokenize
from gensim.utils import simple_preprocess

# %%
# !pip install gensim
# Out:
# Requirement already satisfied: gensim in /opt/conda/lib/python3.10/site-packages (4.3.2)
# Requirement already satisfied: numpy>=1.18.5 in /opt/conda/lib/python3.10/site-packages (from gensim) (1.26.4)
# Requirement already satisfied: scipy>=1.7.0 in /opt/conda/lib/python3.10/site-packages (from gensim) (1.11.4)
# Requirement already satisfied: smart-open>=1.8.1 in /opt/conda/lib/python3.10/site-packages (from gensim) (6.4.0)

# %%
import nltk
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to /usr/share/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
data = ["/kaggle/input/game-of-thrones-books/004ssb.txt","/kaggle/input/game-of-thrones-books/005ssb.txt",
        "/kaggle/input/game-of-thrones-books/001ssb.txt","/kaggle/input/game-of-thrones-books/002ssb.txt",
        "/kaggle/input/game-of-thrones-books/003ssb.txt"]

# %%
story = []
for filepath in data:
    with open(filepath, 'r', encoding='latin-1') as file:
        corpus = file.read()
        raw_sent = sent_tokenize(corpus)
        for sent in raw_sent:
            story.append(simple_preprocess(sent))

# %%
len(story)
# Out:
# 145018

# %%
from sklearn.decomposition import PCA

# %%
model = gensim.models.Word2Vec(window=10,min_count=2)

# %%
model.build_vocab(story)

# %%
model.train(story,total_examples=model.corpus_count, epochs= model.epochs)
# Out:
# (6570958, 8628190)

# %%
model.wv.most_similar("dragon")
# Out:
# [('dynasty', 0.6199306845664978),
#  ('valyria', 0.6113153696060181),
#  ('dragons', 0.6060940623283386),
#  ('god', 0.6057072877883911),
#  ('westeros', 0.5933132171630859),
#  ('tarnished', 0.5843597650527954),
#  ('seven', 0.5775537490844727),
#  ('islands', 0.5771154761314392),
#  ('kingdoms', 0.5754271745681763),
#  ('crown', 0.5720627903938293)]

# %%
model.wv.doesnt_match(['jon','rikon','robb','arya','sansa','bran'])
# Out:
# 'jon'

# %%
model.wv.doesnt_match(['cersei', 'jaime', 'bronn', 'tyrion'])
# Out:
# 'bronn'

# %%
model.wv["jon"]
# Out:
# array([ 6.73626900e-01,  3.59836109e-02,  2.82184362e-01, -1.26253343e+00,
#         1.56470478e+00,  4.87570107e-01,  9.49654400e-01, -5.59892774e-01,
#        -2.87486911e+00,  1.54060528e-01, -1.90698123e+00,  1.08337104e-01,
#        -9.28432643e-01, -1.70999026e+00, -5.81676602e-01,  8.64886582e-01,
#         2.46687412e+00,  1.81681550e+00, -3.00076902e-01, -1.08761823e+00,
#         2.51776171e+00,  8.94983765e-03,  1.59335837e-01,  1.60893500e+00,
#        -1.00442362e+00, -1.00012928e-01, -1.42262423e+00, -1.02254486e+00,
#         2.41797388e-01,  7.02786326e-01, -4.62264389e-01, -7.75835991e-01,
#         9.82378125e-01, -1.55657947e+00,  1.13663983e+00,  1.77017343e+00,
#        -7.52088353e-02,  2.25803518e+00,  1.58154702e+00,  3.30845177e-01,
#        -1.05224562e+00, -1.94530332e+00,  1.02516043e+00,  1.89759111e+00,
#         1.74083734e+00, -2.16406536e+00, -1.66164088e+00,  1.90381837e+00,
#         7.04209089e-01,  2.68318594e-01, -1.69033915e-01, -1.27721214e+00,
#         3.00215578e+00, -6.06446667e-03, -3.32429022e-01, -1.77643907e+00,
#         5.33022225e-01, -3.80727720e+00,  1.43939421e-01,  1.84218779e-01,
#         8.94643545e-01,  1.38768923e+00,  8.21986318e-01, -1.63371235e-01,
#         9.82757568e-01,  9.12942225e-04,  7.09603548e-01,  3.15251398e+00,
#         2.46767953e-01, -2.41043881e-01,  9.13484275e-01, -4.47365642e-01,
#         4.88634169e-01,  3.45714033e-01,  1.48605835e+00,  2.18746305e+00,
#        -2.67735100e+00,  1.85751367e+00,  2.09877238e-01, -4.56345938e-02,
#        -1.36331749e+00, -9.46276963e-01, -1.00742483e+00,  6.45595193e-01,
#        -1.65984952e+00,  1.64188290e+00, -1.53176463e+00, -2.13834807e-01,
#         1.94343120e-01, -2.43518186e+00, -3.14014822e-01,  1.29912508e+00,
#         2.85139382e-01,  1.37699580e+00,  1.42096674e+00, -3.14907932e+00,
#        -5.85561037e-01, -1.74930191e+00,  1.15170848e+00,  8.74715686e-01],
#       dtype=float32)

# %%
model.wv.similarity('arya','sansa')
# Out:
# 0.84823513

# %%
model.wv.similarity('cersei','sansa')
# Out:
# 0.7405536

# %%
model.wv.similarity('tywin','sansa')
# Out:
# 0.2362111

# %%
model.wv.get_normed_vectors()
# Out:
# array([[-0.14389002, -0.02282748, -0.04883049, ..., -0.21866083,
#          0.04911685,  0.20157099],
#        [-0.1889715 , -0.09028026, -0.05134787, ...,  0.06857131,
#         -0.03043398,  0.14598949],
#        [ 0.14600815, -0.02771208, -0.09699386, ..., -0.03972498,
#          0.09346221, -0.17690332],
#        ...,
#        [-0.09563375,  0.04163263,  0.01497037, ..., -0.2012509 ,
#          0.15520681,  0.12130924],
#        [ 0.03140632,  0.07340211, -0.00164953, ...,  0.06731007,
#          0.03994744,  0.11967499],
#        [-0.02687329,  0.07557485, -0.05135947, ..., -0.01817845,
#         -0.06512226,  0.04245527]], dtype=float32)

# %%
y = model.wv.index_to_key

# %%
y[20:30]
# Out:
# ['they', 'is', 'at', 'on', 'said', 'my', 'have', 'be', 'lord', 'them']

# %%
from sklearn.decomposition import PCA  #we are going to use pca to reduce dimentaonality from 100 to 3d space

# %%
pca = PCA(n_components=3)

# %%
X = pca.fit_transform(model.wv.get_normed_vectors())

# %%
X.shape
# Out:
# (17453, 3)

# %%
# !pip install plotly
# Out:
# Requirement already satisfied: plotly in /opt/conda/lib/python3.10/site-packages (5.18.0)
# Requirement already satisfied: tenacity>=6.2.0 in /opt/conda/lib/python3.10/site-packages (from plotly) (8.2.3)
# Requirement already satisfied: packaging in /opt/conda/lib/python3.10/site-packages (from plotly) (21.3)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /opt/conda/lib/python3.10/site-packages (from packaging->plotly) (3.1.1)

# %% [markdown]
# **Visulization**

# %%
import plotly.express as px
fig = px.scatter_3d(X[100:400],x=0,y=1,z=2, color=y[100:400])
fig.show()
# Out:
# /opt/conda/lib/python3.10/site-packages/plotly/express/_core.py:2065: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   sf: grouped.get_group(s if len(s) > 1 else s[0])
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.27.0.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
# <div>                            <div id="5dee29dc-4ed2-46f4-ad83-4640eb56c146" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("5dee29dc-4ed2-46f4-ad83-4640eb56c146")) {                    Plotly.newPlot(                        "5dee29dc-4ed2-46f4-ad83-4640eb56c146",                        [{"hovertemplate":"color=here\u003cbr\u003e0=%{x}\u003cbr\u003e1=%{y}\u003cbr\u003e2=%{z}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"here","marker":{"color":"#636efa","symbol":"circle"},"mode":"markers","name":"here","scene":"scene","showlegend":true,"x":[0.35048118],"y":[0.7171305],"z":[0.015126498],"type":"scatter3d"},{"hovertemplate":"color=through\u003cbr\u003e0=%{x}\u003cbr\u003e1=%{y}\u003cbr\u003e2=%{z}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"through","marker":{"color":"#EF553B","symbol":"circle"},"mode":"markers","name":"through","scene":"scene","showlegend":true,"x":[-0.49013814],"y":[0.40771803],"z":[0.2760171],"type":"scatter3d"},{"hovertemplate":"color=face\u003cbr\u003e0=%{x}\u003cbr\u003e1=%{y}\u003cbr\u003e2=%{z}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"face","marker":{"color":"#00cc96","symbol":"circle"},"mode":"markers","name":"face","scene":"scene","showlegend":true,"x":[-0.18366449],"y":[0.40433082],"z":[0.5184412],"type":"scatter3d"},{"hovertemplate":"color=still\u003cbr\u003e0=%{x}\u003cbr\u003e1=%{y}\u003cbr\u003e2=%{z}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"still","marker":{"color":"#ab63fa","symbol":"circle"},"mode":"markers","name":"still","scene":"scene","showlegend":true,"x":[0.026536515],"y":[0.5772664],"z":[0.11217653],"type":"scatter3d"},{"hovertemplate":"color=head\u003cbr\u003e0=%{x}\u003cbr\u003e1=%{y}\u003cbr\u003e2=%{z}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"head","marker":{"color":"#FFA15A","symbol":"circle"},"mode":"markers","name":"head","scene":"scene","showlegend":true,"x":[-0.18816136],"y":[0.44458073],"z":[0.5392666],"type":"scatter3d"},{"hovertemplate":"color=red\u003cbr\u003e0=%{x}\u003cbr\u003e1=%{y}\u003cbr\u003e2=%{z}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"red","marker":{"color":"#19d3f3","symbol":"circle"},"mode":"markers","name":"red","scene":"scene","showlegend":true,"x":[-0.28504795],"y":[0.32515675],"z":[-0.008933951],"type":"scatter3d"},{"hovertemplate":"color=ll\u003cbr\u003e0=%{x}\u003cbr\u003e1=%{y}\u003cbr\u003e2=%{z}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"ll","marker":{"color":"#FF6692","symbol":"circle"},"mode":"markers","name":"ll","scene":"scene","showlegend":true,"x":[0.36850303],"y":[0.44938767],"z":[0.33815947],"type":"scatter3d"},{"hovertemplate":"color=way\u003cbr\u003e0=%{x}\u003cbr\u003e1=%{y}\u003cbr\u003e2=%{z}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"way","marker":{"color":"#B6E880","symbol":"circle"},"mode":"markers","name":"way","scene":"scene","showlegend":true,"x":[-0.011669975],"y":[0.75344193],"z":[0.25031286],"type":"scatter3d"},{"hovertemplate":"color=boy\u003cbr\u003e0=%{x}\u003cbr\u003e1=%{y}\u003cbr\u003e2=%{z}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"boy","marker":{"color":"#FF97FF","symbol":"circle"},"mode":"markers","name":"boy","scene":"scene","showlegend":true,"x":[0.38854513],"y":[0.34272987],"z":[0.24443555],"type":"scatter3d"},{"hovertemplate":"color=page\u003cbr\u003e0=%{x}\u003cbr\u003e1=%{y}\u003cbr\u003e2=%{z}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"page","marker":{"color":"#FECB52","symbol":"circle"},"mode":"markers","name":"page","scene":"scene","showlegend":true,"x":[0.28370458],"y":[0.36698303],"z":[0.28040865],"type":"scatter3d"},{"hovertemplate":"color=must\u003cbr\u003e0=%{x}\u003cbr\u003e1=%{y}\u003cbr\u003e2=%{z}\u003cextra\u003e\u003c\u002fextra\u003 ...
